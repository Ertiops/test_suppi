# %%
import pandas as pd

# %%
df = pd.read_json("data.json")

# %%
def calc_product_quantity(products):

    quantity_list = []

    for instance in products:
        quantity = 0
        for dictionary in instance:
            quantity += dictionary['quantity']
        quantity_list.append(quantity)
        quantity = 0
    
    return quantity_list

# %%
df_task_1 = df

# %%
df_task_1["highway_rate"] = abs(df_task_1["highway_cost"]) / calc_product_quantity(df_task_1['products'])

# %%
task_1 = df_task_1.drop_duplicates(subset=["warehouse_name"])
task_1_result = task_1[["warehouse_name", "highway_rate"]]
print('Ответ на задание 1:\n\n', task_1_result)
# Out:
# Ответ на задание 1:
#
#          warehouse_name  highway_rate
# 0               Мордор          10.0
# 1  хутор близ Диканьки          15.0
# 2           отель Лето          25.0
# 5     остров невезения           5.0
# 6           гиперборея          20.0

# %%
def calcuate_task_2(df):
    dataframe = {'product':[],'warehouse_name':[], 'quantity':[], 'income':[], 'expenses': [], 'profit':[]}

    for index, row in df_task_1.iterrows():
        for dictionary in row['products']:

            dataframe['product'].append(dictionary['product'])

            dataframe['warehouse_name'].append(row['warehouse_name'])

            dataframe['quantity'].append(dictionary['quantity'])

            income = dictionary['quantity'] * dictionary['price']
            dataframe['income'].append(income)

            expenses = row['highway_rate'] * dictionary['quantity']               
            dataframe['expenses'].append(expenses)

            profit = income - expenses                
            dataframe['profit'].append(profit)

    result = pd.DataFrame(data=dataframe)
    result = result[['quantity', 'income','expenses', 'profit']].sum()

    return result

# %%
task_2_result = calcuate_task_2(df_task_1)
print('Ответ на задание 2:\n\n', task_2_result)
# Out:
# Ответ на задание 2:
#
#  quantity       375.0
# income      141110.0
# expenses      5880.0
# profit      135230.0
# dtype: float64

# %%
def calcuate_task_3(df):
    dataframe = {'order_id':[],'order_profit':[]}

    for index, row in df_task_1.iterrows():
        
        dataframe['order_id'].append(row['order_id'])
                
        order_income = 0
        order_expense = 0
        
        for dictionary in row['products']:                        

            order_income += dictionary['price'] * dictionary['quantity']
            
            order_expense += dictionary['quantity'] * row['highway_rate']
            
        order_profit = order_income - order_expense
        
        dataframe['order_profit'].append(order_profit)

    result = pd.DataFrame(data=dataframe)

    return result

# %%
task_3_result = calcuate_task_3(df_task_1)

# %%
print('Ответ на задание 3 часть 1:')     
task_3_result
# Out:
# Ответ на задание 3 часть 1:
#     order_id  order_profit
# 0      11973        3980.0
# 1      62239         985.0
# 2      85794         -30.0
# 3      33684        1980.0
# 4      25824         975.0
# ..       ...           ...
# 95     28106         320.0
# 96     98100        1590.0
# 97     79293        1175.0
# 98      2930         720.0
# 99       124         705.0
#
# [100 rows x 2 columns]

# %%
print('Ответ на задание 3 часть 2 (средняя прибыль с заказа): ', task_3_result['order_profit'].mean())
# Out:
# Ответ на задание 3 часть 2 (средняя прибыль с заказа):  1352.3

# %%
def calcuate_task_4(df):
    
    dataframe = {'warehouse_name':[], 'product':[], 'quantity':[], 'profit':[], 'percent_profit_product_of_warehouse':[]}

    grouped_by_warehouse = df.groupby(['warehouse_name'])

    group_names = grouped_by_warehouse.groups.keys()

    for group in group_names:

        group_data = grouped_by_warehouse.get_group(group)

        group_products = {}

        for index, row in group_data.iterrows():
            for dictionary in row['products']:
                if dictionary['product'] not in group_products:
                    group_products[dictionary['product']] = {'quantity': dictionary['quantity'], 
                                                             'rate': row['highway_rate'],
                                                             'price': dictionary['price'] }

                elif dictionary['product'] in group_products:
                    group_products[dictionary['product']]['quantity'] += dictionary['quantity']



        product_income = 0
        product_expense = 0

        for product in group_products:
            rate = group_products[product]['rate']
            price = group_products[product]['price']
            quantity = group_products[product]['quantity']

            product_income += price * quantity

            product_expense += quantity * rate

        warehouse_profit = product_income - product_expense

        product_income = 0
        product_expense = 0


        for product in group_products:

            dataframe['warehouse_name'].append(group)
            dataframe['product'].append(product)

            quantity = group_products[product]['quantity']
            price = group_products[product]['price']
            rate = group_products[product]['rate']

            dataframe['quantity'].append(quantity)

            profit = quantity * price - quantity * rate

            dataframe['profit'].append(profit)

            profit_percentage = profit / warehouse_profit

            dataframe['percent_profit_product_of_warehouse'].append(profit_percentage)
            
    result = pd.DataFrame(data=dataframe)
    
    return result

# %%
task_4_result = calcuate_task_4(df_task_1)

# %%
print('Ответ на задание 4:')
task_4_result
# Out:
# Ответ на задание 4:
#          warehouse_name                   product  quantity   profit  \
# 0                Мордор     ломтик июльского неба         3   1320.0
# 1                Мордор           билет в Израиль         9   8910.0
# 2                Мордор          статуэтка Ленина        10   1900.0
# 3                Мордор         зеленая пластинка        11      0.0
# 4                Мордор  автограф Стаса Барецкого         4   2360.0
# 5                Мордор    подписка на suppi-блог         8   1120.0
# 6                Мордор                   плюмбус         6   1440.0
# 7            гиперборея                   плюмбус         9   2070.0
# 8            гиперборея          статуэтка Ленина         9   1620.0
# 9            гиперборея     ломтик июльского неба        13   5590.0
# 10           гиперборея         зеленая пластинка        10   -100.0
# 11           гиперборея           билет в Израиль        21  20580.0
# 12           гиперборея  автограф Стаса Барецкого        12   6960.0
# 13           гиперборея    подписка на suppi-блог        12   1560.0
# 14     остров невезения                   плюмбус        14   3430.0
# 15     остров невезения          статуэтка Ленина        18   3510.0
# 16     остров невезения     ломтик июльского неба        10   4450.0
# 17     остров невезения  автограф Стаса Барецкого         2   1190.0
# 18     остров невезения           билет в Израиль         3   2985.0
# 19     остров невезения         зеленая пластинка         9     45.0
# 20           отель Лето         зеленая пластинка        10   -150.0
# 21           отель Лето  автограф Стаса Барецкого         8   4600.0
# 22           отель Лето          статуэтка Ленина        10   1750.0
# 23           отель Лето                   плюмбус         9   2025.0
# 24           отель Лето           билет в Израиль        15  14625.0
# 25           отель Лето     ломтик июльского неба         9   3825.0
# 26           отель Лето    подписка на suppi-блог         3    375.0
# 27  хутор близ Диканьки           билет в Израиль        10   9850.0
# 28  хутор близ Диканьки                   плюмбус        27   6345.0
# 29  хутор близ Диканьки         зеленая пластинка        21   -105.0
# 30  хутор близ Диканьки    подписка на suppi-блог        10   1350.0
# 31  хутор близ Диканьки          статуэтка Ленина        21   3885.0
# 32  хутор близ Диканьки     ломтик июльского неба         7   3045.0
# 33  хутор близ Диканьки  автограф Стаса Барецкого        22  12870.0
#
#     percent_profit_product_of_warehouse
# 0                              0.077419
# 1                              0.522581
# 2                              0.111437
# 3                              0.000000
# 4                              0.138416
# 5                              0.065689
# 6                              0.084457
# 7                              0.054075
# 8                              0.042320
# 9                              0.146029
# 10                            -0.002612
# 11                             0.537618
# 12                             0.181818
# 13                             0.040752
# 14                             0.219731
# 15                             0.224856
# 16                             0.285074
# 17                             0.076233
# 18                             0.191224
# 19                             0.002883
# 20                            -0.005545
# 21                             0.170055
# 22                             0.064695
# 23                             0.074861
# 24                             0.540665
# 25                             0.141405
# 26                             0.013863
# 27                             0.264501
# 28                             0.170381
# 29                            -0.002820
# 30                             0.036251
# 31                             0.104323
# 32                             0.081767
# 33                             0.345596

# %%
df_task_5 =  task_4_result.sort_values(['warehouse_name','percent_profit_product_of_warehouse'],ascending=False).groupby('warehouse_name')

# %%
def calcuate_task_5(df):
    dataframe = {'warehouse_name':[], 'product':[], 'quantity':[], 'profit':[], 
                 'percent_profit_product_of_warehouse':[], 'accumulated_percent_profit_product_of_warehouse':[]}

    group_names = df.groups.keys()

    for group in group_names: 

        group_data = df.get_group(group)

        accumulated_percentage = 0

        for index, row in group_data.iterrows():
            dataframe['warehouse_name'].append(row['warehouse_name'])
            dataframe['product'].append(row['product'])
            dataframe['quantity'].append(row['quantity'])
            dataframe['profit'].append(row['profit'])
            dataframe['percent_profit_product_of_warehouse'].append(row['percent_profit_product_of_warehouse'])

            accumulated_percentage += row['percent_profit_product_of_warehouse']

            dataframe['accumulated_percent_profit_product_of_warehouse'].append(accumulated_percentage)


    result = pd.DataFrame(data=dataframe)   

    return result

# %%
result_task_5 = calcuate_task_5(df_task_5)

# %%
print('Ответ на задание 5:')
result_task_5
# Out:
# Ответ на задание 5:
#          warehouse_name                   product  quantity   profit  \
# 0                Мордор           билет в Израиль         9   8910.0
# 1                Мордор  автограф Стаса Барецкого         4   2360.0
# 2                Мордор          статуэтка Ленина        10   1900.0
# 3                Мордор                   плюмбус         6   1440.0
# 4                Мордор     ломтик июльского неба         3   1320.0
# 5                Мордор    подписка на suppi-блог         8   1120.0
# 6                Мордор         зеленая пластинка        11      0.0
# 7            гиперборея           билет в Израиль        21  20580.0
# 8            гиперборея  автограф Стаса Барецкого        12   6960.0
# 9            гиперборея     ломтик июльского неба        13   5590.0
# 10           гиперборея                   плюмбус         9   2070.0
# 11           гиперборея          статуэтка Ленина         9   1620.0
# 12           гиперборея    подписка на suppi-блог        12   1560.0
# 13           гиперборея         зеленая пластинка        10   -100.0
# 14     остров невезения     ломтик июльского неба        10   4450.0
# 15     остров невезения          статуэтка Ленина        18   3510.0
# 16     остров невезения                   плюмбус        14   3430.0
# 17     остров невезения           билет в Израиль         3   2985.0
# 18     остров невезения  автограф Стаса Барецкого         2   1190.0
# 19     остров невезения         зеленая пластинка         9     45.0
# 20           отель Лето           билет в Израиль        15  14625.0
# 21           отель Лето  автограф Стаса Барецкого         8   4600.0
# 22           отель Лето     ломтик июльского неба         9   3825.0
# 23           отель Лето                   плюмбус         9   2025.0
# 24           отель Лето          статуэтка Ленина        10   1750.0
# 25           отель Лето    подписка на suppi-блог         3    375.0
# 26           отель Лето         зеленая пластинка        10   -150.0
# 27  хутор близ Диканьки  автограф Стаса Барецкого        22  12870.0
# 28  хутор близ Диканьки           билет в Израиль        10   9850.0
# 29  хутор близ Диканьки                   плюмбус        27   6345.0
# 30  хутор близ Диканьки          статуэтка Ленина        21   3885.0
# 31  хутор близ Диканьки     ломтик июльского неба         7   3045.0
# 32  хутор близ Диканьки    подписка на suppi-блог        10   1350.0
# 33  хутор близ Диканьки         зеленая пластинка        21   -105.0
#
#     percent_profit_product_of_warehouse  \
# 0                              0.522581
# 1                              0.138416
# 2                              0.111437
# 3                              0.084457
# 4                              0.077419
# 5                              0.065689
# 6                              0.000000
# 7                              0.537618
# 8                              0.181818
# 9                              0.146029
# 10                             0.054075
# 11                             0.042320
# 12                             0.040752
# 13                            -0.002612
# 14                             0.285074
# 15                             0.224856
# 16                             0.219731
# 17                             0.191224
# 18                             0.076233
# 19                             0.002883
# 20                             0.540665
# 21                             0.170055
# 22                             0.141405
# 23                             0.074861
# 24                             0.064695
# 25                             0.013863
# 26                            -0.005545
# 27                             0.345596
# 28                             0.264501
# 29                             0.170381
# 30                             0.104323
# 31                             0.081767
# 32                             0.036251
# 33                            -0.002820
#
#     accumulated_percent_profit_product_of_warehouse
# 0                                          0.522581
# 1                                          0.660997
# 2                                          0.772434
# 3                                          0.856891
# 4                                          0.934311
# 5                                          1.000000
# 6                                          1.000000
# 7                                          0.537618
# 8                                          0.719436
# 9                                          0.865465
# 10                                         0.919540
# 11                                         0.961860
# 12                                         1.002612
# 13                                         1.000000
# 14                                         0.285074
# 15                                         0.509930
# 16                                         0.729660
# 17                                         0.920884
# 18                                         0.997117
# 19                                         1.000000
# 20                                         0.540665
# 21                                         0.710721
# 22                                         0.852126
# 23                                         0.926987
# 24                                         0.991682
# 25                                         1.005545
# 26                                         1.000000
# 27                                         0.345596
# 28                                         0.610097
# 29                                         0.780478
# 30                                         0.884801
# 31                                         0.966568
# 32                                         1.002820
# 33                                         1.000000

# %%
df_task_6 = result_task_5

# %%
def ranger(number):
    if number <= 0.7:
        return 'A'        
    elif 0.7 < number <= 0.9:
        return 'B'
    elif number > 0.9:
        return 'C'

# %%
df_task_6['category'] = df_task_6['accumulated_percent_profit_product_of_warehouse'].apply(ranger)
result_task_6 = df_task_6

# %%
print('Ответ на задание 6:')
result_task_6
# Out:
# Ответ на задание 6:
#          warehouse_name                   product  quantity   profit  \
# 0                Мордор           билет в Израиль         9   8910.0
# 1                Мордор  автограф Стаса Барецкого         4   2360.0
# 2                Мордор          статуэтка Ленина        10   1900.0
# 3                Мордор                   плюмбус         6   1440.0
# 4                Мордор     ломтик июльского неба         3   1320.0
# 5                Мордор    подписка на suppi-блог         8   1120.0
# 6                Мордор         зеленая пластинка        11      0.0
# 7            гиперборея           билет в Израиль        21  20580.0
# 8            гиперборея  автограф Стаса Барецкого        12   6960.0
# 9            гиперборея     ломтик июльского неба        13   5590.0
# 10           гиперборея                   плюмбус         9   2070.0
# 11           гиперборея          статуэтка Ленина         9   1620.0
# 12           гиперборея    подписка на suppi-блог        12   1560.0
# 13           гиперборея         зеленая пластинка        10   -100.0
# 14     остров невезения     ломтик июльского неба        10   4450.0
# 15     остров невезения          статуэтка Ленина        18   3510.0
# 16     остров невезения                   плюмбус        14   3430.0
# 17     остров невезения           билет в Израиль         3   2985.0
# 18     остров невезения  автограф Стаса Барецкого         2   1190.0
# 19     остров невезения         зеленая пластинка         9     45.0
# 20           отель Лето           билет в Израиль        15  14625.0
# 21           отель Лето  автограф Стаса Барецкого         8   4600.0
# 22           отель Лето     ломтик июльского неба         9   3825.0
# 23           отель Лето                   плюмбус         9   2025.0
# 24           отель Лето          статуэтка Ленина        10   1750.0
# 25           отель Лето    подписка на suppi-блог         3    375.0
# 26           отель Лето         зеленая пластинка        10   -150.0
# 27  хутор близ Диканьки  автограф Стаса Барецкого        22  12870.0
# 28  хутор близ Диканьки           билет в Израиль        10   9850.0
# 29  хутор близ Диканьки                   плюмбус        27   6345.0
# 30  хутор близ Диканьки          статуэтка Ленина        21   3885.0
# 31  хутор близ Диканьки     ломтик июльского неба         7   3045.0
# 32  хутор близ Диканьки    подписка на suppi-блог        10   1350.0
# 33  хутор близ Диканьки         зеленая пластинка        21   -105.0
#
#     percent_profit_product_of_warehouse  \
# 0                              0.522581
# 1                              0.138416
# 2                              0.111437
# 3                              0.084457
# 4                              0.077419
# 5                              0.065689
# 6                              0.000000
# 7                              0.537618
# 8                              0.181818
# 9                              0.146029
# 10                             0.054075
# 11                             0.042320
# 12                             0.040752
# 13                            -0.002612
# 14                             0.285074
# 15                             0.224856
# 16                             0.219731
# 17                             0.191224
# 18                             0.076233
# 19                             0.002883
# 20                             0.540665
# 21                             0.170055
# 22                             0.141405
# 23                             0.074861
# 24                             0.064695
# 25                             0.013863
# 26                            -0.005545
# 27                             0.345596
# 28                             0.264501
# 29                             0.170381
# 30                             0.104323
# 31                             0.081767
# 32                             0.036251
# 33                            -0.002820
#
#     accumulated_percent_profit_product_of_warehouse category
# 0                                          0.522581        A
# 1                                          0.660997        A
# 2                                          0.772434        B
# 3                                          0.856891        B
# 4                                          0.934311        C
# 5                                          1.000000        C
# 6                                          1.000000        C
# 7                                          0.537618        A
# 8                                          0.719436        B
# 9                                          0.865465        B
# 10                                         0.919540        C
# 11                                         0.961860        C
# 12                                         1.002612        C
# 13                                         1.000000        C
# 14                                         0.285074        A
# 15                                         0.509930        A
# 16                                         0.729660        B
# 17                                         0.920884        C
# 18                                         0.997117        C
# 19                                         1.000000        C
# 20                                         0.540665        A
# 21                                         0.710721        B
# 22                                         0.852126        B
# 23                                         0.926987        C
# 24                                         0.991682        C
# 25                                         1.005545        C
# 26                                         1.000000        C
# 27                                         0.345596        A
# 28                                         0.610097        A
# 29                                         0.780478        B
# 30                                         0.884801        B
# 31                                         0.966568        C
# 32                                         1.002820        C
# 33                                         1.000000        C
